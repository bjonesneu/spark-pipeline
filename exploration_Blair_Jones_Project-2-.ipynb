# %% [markdown]
# # Observations on the data
#
# ## Remaining questions
# - Are the test stats correct?  For example:
#     - Do the summary stats agree with the detailed data for each test? NO !!!
#     - Is all_correct calculated correctly 'within' the summary stats?
# - Are there duplicates?
# - What is the structure of a question?
#
# ## The data:
# - Overall structure
#     + exam
#         + question
#             + result
# - Contains 1 object per test administered per student
# - Each object contains metadata about the test and the results
#
# ## Key Fields
# - Exam ID
# - Exam_name = string
# - Certification = boolean
# - ['sequences']['counts'] = 7 fields that provide summary of test outcomes for the student, for example: number of questions, number correct, number wrong

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import SVG

import json

# %%
with open('./assessment-attempts-20180128-121051-nested.json') as json_file:
    data = json.load(json_file)

# %%
len(data)
# Out:
# 3280

# %%
data[0]
# Out:
# {'keen_timestamp': '1516717442.735266',
#  'max_attempts': '1.0',
#  'started_at': '2018-01-23T14:23:19.082Z',
#  'base_exam_id': '37f0a30a-7464-11e6-aa92-a8667f27e5dc',
#  'user_exam_id': '6d4089e4-bde5-4a22-b65f-18bce9ab79c8',
#  'sequences': {'questions': [{'user_incomplete': True,
#     'user_correct': False,
#     'options': [{'checked': True,
#       'at': '2018-01-23T14:23:24.670Z',
#       'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d',
#       'submitted': 1,
#       'correct': True},
#      {'checked': True,
#       'at': '2018-01-23T14:23:25.914Z',
#       'id': 'f2528210-35c3-4320-acf3-9056567ea19f',
#       'submitted': 1,
#       'correct': True},
#      {'checked': False,
#       'correct': True,
#       'id': 'd1bf026f-554f-4543-bdd2-54dcf105b826'}],
#     'user_submitted': True,
#     'id': '7a2ed6d3-f492-49b3-b8aa-d080a8aad986',
#     'user_result': 'missed_some'},
#    {'user_incomplete': False,
#     'user_correct': False,
#     'options': [{'checked': True,
#       'at': '2018-01-23T14:23:30.116Z',
#       'id': 'a35d0e80-8c49-415d-b8cb-c21a02627e2b',
#       'submitted': 1},
#      {'checked': False,
#       'correct': True,
#       'id': 'bccd6e2e-2cef-4c72-8bfa-317db0ac48bb'},
#      {'checked': True,
#       'at': '2018-01-23T14:23:41.791Z',
#       'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': 'bbed4358-999d-4462-9596-bad5173a6ecb',
#     'user_result': 'incorrect'},
#    {'user_incomplete': False,
#     'user_correct': True,
#     'options': [{'checked': False,
#       'at': '2018-01-23T14:23:52.510Z',
#       'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732'},
#      {'checked': False, 'id': '85795acc-b4b1-4510-bd6e-41648a3553c9'},
#      {'checked': True,
#       'at': '2018-01-23T14:23:54.223Z',
#       'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909',
#       'submitted': 1,
#       'correct': True},
#      {'checked': True,
#       'at': '2018-01-23T14:23:53.862Z',
#       'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': 'e6ad8644-96b1-4617-b37b-a263dded202c',
#     'user_result': 'correct'},
#    {'user_incomplete': False,
#     'user_correct': True,
#     'options': [{'checked': False,
#       'id': '59b9fc4b-f239-4850-b1f9-912d1fd3ca13'},
#      {'checked': False, 'id': '2c29e8e8-d4a8-406e-9cdf-de28ec5890fe'},
#      {'checked': False, 'id': '62feee6e-9b76-4123-bd9e-c0b35126b1f1'},
#      {'checked': True,
#       'at': '2018-01-23T14:24:00.807Z',
#       'id': '7f13df9c-fcbe-4424-914f-2206f106765c',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': '95194331-ac43-454e-83de-ea8913067055',
#     'user_result': 'correct'}],
#   'attempt': 1,
#   'id': '5b28a462-7a3b-42e0-b508-09f3906d1703',
#   'counts': {'incomplete': 1,
#    'submitted': 4,
#    'incorrect': 1,
#    'all_correct': False,
#    'correct': 2,
#    'total': 4,
#    'unanswered': 0}},
#  'keen_created_at': '1516717442.735266',
#  'certification': 'false',
#  'keen_id': '5a6745820eb8ab00016be1f1',
#  'exam_name': 'Normal Forms and All That Jazz Master Class'}

# %%
# already verified that all have sequence field
len_sequences = []
len_questions = []

for item in data:
    len_sequences.append(len(item['sequences']))
    len_questions.append(len(item['sequences']['questions']))

print('# sequences range from', min(len_sequences), 'to', max(len_sequences))
print('# questions per sequence range from', min(len_questions), 'to', max(len_questions))
print('# questions total', sum(len_questions))
# Out:
# # sequences range from 3 to 4
# # questions per sequence range from 1 to 20
# # questions total 14717

# %%
for item in data[0]['sequences']:
    print(item)
# Out:
# questions
# attempt
# id
# counts

# %%
# determine number of assessments that have fewer than 4 sequence entries
outliers = []
for item in data:
    if len(item['sequences']) < 4:
        outliers.append(item)

print(len(outliers), 'assessments have different number of sequences out of total of', len(len_sequences))
# Out:
# 5 assessments have different number of sequences out of total of 3280

# %%
# this is to examine the assessments that have fewer than 4 sequence entries, trying to understand the difference
for item in outliers:
    print(item, '\n')
# Out:
# {'keen_timestamp': '1515770320.8660779', 'max_attempts': '1.0', 'started_at': '2018-01-12T15:18:36.145Z', 'base_exam_id': 'example-id', 'user_exam_id': '2c6eab33-a584-464e-b020-d5822653c46f', 'sequences': {'attempt': 1, 'id': '9b2f7400-91fd-4e7c-b19e-0ce20d2bc675', 'questions': [{'options': [{'checked': False, 'correct': True, 'id': 'e3b27b55-3818-4721-abe3-0fd4aee9c0ab'}, {'checked': False, 'id': '8001e149-88c1-43ef-970a-0c6108035e94'}, {'checked': True, 'at': '2018-01-12T15:18:39.167Z', 'id': '66dcb9d1-3692-4327-b62b-167c72f52949'}], 'id': '69e7297c-1433-4e9f-8585-5f09c78ddbad'}, {'options': [{'checked': False, 'id': '55eed25e-8cd8-46fc-9ea4-0b7377ce425d'}, {'checked': False, 'correct': True, 'id': '4a329ac6-052e-45db-a0a5-b2941a62d5cf'}], 'id': '3686549f-5f1d-4875-a42b-663c402fc9ed'}, {'options': [{'checked': False, 'id': '53455293-2275-4c16-8fed-da19d47cfd18'}, {'checked': False, 'correct': True, 'id': '94d7c6c3-1212-45da-b1ce-4ea1c91df3dc'}], 'id': 'f47b04b5-5f44-45a7-9605-635461eabcbf'}]}, 'keen_created_at': '1515770320.8660779', 'certification': 'false', 'keen_id': '5a58d1d0adc44600016d09af', 'exam_name': 'Example Exam For Development and Testing oh yeahsdf'}
#
# {'keen_timestamp': '1515770445.4553161', 'max_attempts': '1.0', 'started_at': '2018-01-12T15:20:42.115Z', 'base_exam_id': 'example-id', 'user_exam_id': 'f5a840e8-1836-41d0-ace1-3ece0663ac1e', 'sequences': {'attempt': 1, 'id': '9b2f7400-91fd-4e7c-b19e-0ce20d2bc675', 'questions': [{'options': [{'checked': False, 'correct': True, 'id': 'ec67796b-5352-4c97-b19f-a06481671e5a'}, {'checked': True, 'at': '2018-01-12T15:20:43.612Z', 'id': '1c8dec87-4882-43ee-bf9e-28a5ce31ec3d'}, {'checked': False, 'correct': True, 'id': '53867f87-e28d-4751-bf26-2c7addb2cb89'}], 'id': 'd5139ee6-d0ad-4bbf-9efd-280b64daa447'}, {'options': [{'checked': False, 'id': '53455293-2275-4c16-8fed-da19d47cfd18'}, {'checked': False, 'correct': True, 'id': '94d7c6c3-1212-45da-b1ce-4ea1c91df3dc'}], 'id': 'f47b04b5-5f44-45a7-9605-635461eabcbf'}, {'options': [{'checked': False, 'correct': True, 'id': '4a329ac6-052e-45db-a0a5-b2941a62d5cf'}, {'checked': False, 'id': '55eed25e-8cd8-46fc-9ea4-0b7377ce425d'}], 'id': '3686549f-5f1d-4875-a42b-663c402fc9ed'}]}, 'keen_created_at': '1515770445.4553161', 'certification': 'false', 'keen_id': '5a58d24de4766800011b1bb0', 'exam_name': 'Example Exam For Development and Testing oh yeahsdf'}
#
# {'keen_timestamp': '1515769654.4050341', 'max_attempts': '1.0', 'started_at': '2018-01-12T15:07:27.184Z', 'base_exam_id': 'example-id', 'user_exam_id': '21332e91-dbae-46b8-81db-d62788ae7614', 'sequences': {'attempt': 1, 'id': '9b2f7400-91fd-4e7c-b19e-0ce20d2bc675', 'questions': [{'options': [{'checked': True, 'at': '2018-01-12T15:07:28.994Z', 'id': '94d7c6c3-1212-45da-b1ce-4ea1c91df3dc', 'correct': True}, {'checked': False, 'id': '53455293-2275-4c16-8fed-da19d47cfd18'}], 'id': 'f47b04b5-5f44-45a7-9605-635461eabcbf'}, {'options': [{'checked': False, 'id': '55eed25e-8cd8-46fc-9ea4-0b7377ce425d'}, {'checked': False, 'correct': True, 'id': '4a329ac6-052e-45db-a0a5-b2941a62d5cf'}], 'id': '3686549f-5f1d-4875-a42b-663c402fc9ed'}, {'options': [{'checked': False, 'correct': True, 'id': 'e3b27b55-3818-4721-abe3-0fd4aee9c0ab'}, {'checked': False, 'id': '66dcb9d1-3692-4327-b62b-167c72f52949'}, {'checked': False, 'id': '8001e149-88c1-43ef-970a-0c6108035e94'}], 'id': '69e7297c-1433-4e9f-8585-5f09c78ddbad'}]}, 'keen_created_at': '1515769654.4050341', 'certification': 'false', 'keen_id': '5a58cf366eb1a50001380527', 'exam_name': 'Example Exam For Development and Testing oh yeahsdf'}
#
# {'keen_timestamp': '1511285889.6726379', 'max_attempts': '1.0', 'started_at': '2017-11-21T17:38:06.179Z', 'base_exam_id': 'example-id', 'user_exam_id': 'ba0677f0-88e4-43c8-947b-6393e8cd1797', 'sequences': {'attempt': 1, 'id': '9b2f7400-91fd-4e7c-b19e-0ce20d2bc675', 'questions': [{'options': [{'checked': False, 'correct': True, 'id': '4a329ac6-052e-45db-a0a5-b2941a62d5cf'}, {'checked': False, 'id': '55eed25e-8cd8-46fc-9ea4-0b7377ce425d'}], 'id': '3686549f-5f1d-4875-a42b-663c402fc9ed'}, {'options': [{'checked': False, 'correct': True, 'id': 'ec67796b-5352-4c97-b19f-a06481671e5a'}, {'checked': False, 'id': '1c8dec87-4882-43ee-bf9e-28a5ce31ec3d'}, {'checked': False, 'correct': True, 'id': '53867f87-e28d-4751-bf26-2c7addb2cb89'}], 'id': 'd5139ee6-d0ad-4bbf-9efd-280b64daa447'}, {'options': [{'checked': False, 'id': '20ba55f9-26cc-4967-b447-bd4a87885025'}, {'checked': True, 'at': '2017-11-21T17:38:08.228Z', 'id': 'f1dcff4e-1bca-4d6d-8bdb-570beed81f10', 'correct': True}], 'id': 'c6c00a26-eb1e-426d-a9a7-8dd9c7166431'}]}, 'keen_created_at': '1511285889.6726379', 'certification': 'false', 'keen_id': '5a146481407c320001ff73eb', 'exam_name': 'Example Exam For Development and Testing oh yeahsdf'}
#
# {'keen_timestamp': '1511285850.6714621', 'max_attempts': '1.0', 'started_at': '2017-11-21T17:35:52.239Z', 'base_exam_id': 'example-id', 'user_exam_id': '2293650d-155a-4819-a650-6c677c8442b0', 'sequences': {'attempt': 1, 'id': '9b2f7400-91fd-4e7c-b19e-0ce20d2bc675', 'questions': [{'options': [{'checked': True, 'at': '2017-11-21T17:37:26.810Z', 'id': 'f1dcff4e-1bca-4d6d-8bdb-570beed81f10', 'correct': True}, {'checked': False, 'id': '20ba55f9-26cc-4967-b447-bd4a87885025'}], 'id': 'c6c00a26-eb1e-426d-a9a7-8dd9c7166431'}, {'options': [{'checked': False, 'at': '2017-11-21T17:37:27.985Z', 'id': '66dcb9d1-3692-4327-b62b-167c72f52949'}, {'checked': True, 'at': '2017-11-21T17:37:28.645Z', 'id': 'e3b27b55-3818-4721-abe3-0fd4aee9c0ab', 'correct': True}, {'checked': False, 'id': '8001e149-88c1-43ef-970a-0c6108035e94'}], 'id': '69e7297c-1433-4e9f-8585-5f09c78ddbad'}, {'options': [{'checked': False, 'correct': True, 'id': '4a329ac6-052e-45db-a0a5-b2941a62d5cf'}, {'checked': False, 'id': '55eed25e-8cd8-46fc-9ea4-0b7377ce425d'}], 'id': '3686549f-5f1d-4875-a42b-663c402fc9ed'}]}, 'keen_created_at': '1511285850.6714621', 'certification': 'false', 'keen_id': '5a14645a2de8f90001ae4120', 'exam_name': 'Example Exam For Development and Testing oh yeahsdf'}

# %% [markdown]
# All 5 had the same description "Example Exam For Development and Testing oh yeahsdf".
# This implies these 5 are not for production and should therefore be removed from the dataset.

# %%
# checking for other outliers
others = []
for item in data:
    if item['exam_name'].find('yeahsdf') > -1:
        others.append(item)
    elif item['exam_name'].find('Example Exam') > -1:
        others.append(item)
    elif item['base_exam_id'].find('example') > -1:
        others.append(item)

print(len(others))
# Out:
# 5

# %% [markdown]
# So based on this there are only 5 "development" assessments to ignore

# %%
df_questions = pd.DataFrame()
assessment_ids = []
exam_ids = []
exam_started = []
exam_names = []
questions = []
for item in data:
    if item['exam_name'].find('yeahsdf') > -1:
        continue
    for question in item['sequences']['questions']:
        assessment_ids.append(item['keen_id'])
        exam_ids.append(item['base_exam_id'])
        exam_started.append(item['started_at'])
        exam_names.append(item['exam_name'])
#        exams.append(item['exam_name'])
        questions.append(question)

# %%
df_questions = pd.DataFrame()
df_questions['assessment_id'] = assessment_ids
df_questions['exam_id'] = exam_ids
df_questions['started_at'] = exam_started
df_questions['name'] = exam_names
df_questions['question'] = questions

# %%
df_questions
# Out:
#                   assessment_id                               exam_id  \
# 0      5a6745820eb8ab00016be1f1  37f0a30a-7464-11e6-aa92-a8667f27e5dc
# 1      5a6745820eb8ab00016be1f1  37f0a30a-7464-11e6-aa92-a8667f27e5dc
# 2      5a6745820eb8ab00016be1f1  37f0a30a-7464-11e6-aa92-a8667f27e5dc
# 3      5a6745820eb8ab00016be1f1  37f0a30a-7464-11e6-aa92-a8667f27e5dc
# 4      5a674541ab6b0a0001c6e723  37f0a30a-7464-11e6-aa92-a8667f27e5dc
# ...                         ...                                   ...
# 14697  5a3a3df2448eb200012a2efd  a62e5d35-75e9-11e6-8197-9801a7c3b233
# 14698  5a3a3df2448eb200012a2efd  a62e5d35-75e9-11e6-8197-9801a7c3b233
# 14699  5a3a3df2448eb200012a2efd  a62e5d35-75e9-11e6-8197-9801a7c3b233
# 14700  5a3a3df2448eb200012a2efd  a62e5d35-75e9-11e6-8197-9801a7c3b233
# 14701  5a3a3df2448eb200012a2efd  a62e5d35-75e9-11e6-8197-9801a7c3b233
#
#                      started_at                                         name  \
# 0      2018-01-23T14:23:19.082Z  Normal Forms and All That Jazz Master Class
# 1      2018-01-23T14:23:19.082Z  Normal Forms and All That Jazz Master Class
# 2      2018-01-23T14:23:19.082Z  Normal Forms and All That Jazz Master Class
# 3      2018-01-23T14:23:19.082Z  Normal Forms and All That Jazz Master Class
# 4      2018-01-23T14:21:47.505Z  Normal Forms and All That Jazz Master Class
# ...                         ...                                          ...
# 14697  2017-12-20T10:38:26.490Z         Learning Linux System Administration
# 14698  2017-12-20T10:38:26.490Z         Learning Linux System Administration
# 14699  2017-12-20T10:38:26.490Z         Learning Linux System Administration
# 14700  2017-12-20T10:38:26.490Z         Learning Linux System Administration
# 14701  2017-12-20T10:38:26.490Z         Learning Linux System Administration
#
#                                                 question
# 0      {'user_incomplete': True, 'user_correct': Fals...
# 1      {'user_incomplete': False, 'user_correct': Fal...
# 2      {'user_incomplete': False, 'user_correct': Tru...
# 3      {'user_incomplete': False, 'user_correct': Tru...
# 4      {'user_incomplete': False, 'user_correct': Tru...
# ...                                                  ...
# 14697  {'user_incomplete': False, 'user_correct': Tru...
# 14698  {'user_incomplete': False, 'user_correct': Tru...
# 14699  {'user_incomplete': False, 'user_correct': Tru...
# 14700  {'user_incomplete': False, 'user_correct': Fal...
# 14701  {'user_incomplete': False, 'user_correct': Fal...
#
# [14702 rows x 5 columns]

# %%
#plt.hist(df_questions['started_at'])

# %%
df_questions[110:120]['name']
# Out:
# 110                Learning iPython Notebook
# 111                   Introduction to Python
# 112                   Introduction to Python
# 113                   Introduction to Python
# 114                   Introduction to Python
# 115                   Introduction to Python
# 116    Beginning Programming with JavaScript
# 117    Beginning Programming with JavaScript
# 118    Beginning Programming with JavaScript
# 119    Beginning Programming with JavaScript
# Name: name, dtype: object

# %%
data[5]['sequences']['attempt']
# Out:
# 1

# %%
len_counts = []

for item in data:
    if item['exam_name'].find('yeahsdf') > -1:
        continue

    len_counts.append(len(item['sequences']['counts']))

print('# counts range from', min(len_counts), 'to', max(len_counts))
# Out:
# # counts range from 7 to 7

# %%
data[0]['sequences']['counts']
# Out:
# {'incomplete': 1,
#  'submitted': 4,
#  'incorrect': 1,
#  'all_correct': False,
#  'correct': 2,
#  'total': 4,
#  'unanswered': 0}

# %%
df_exams = pd.DataFrame()
exam_ids = []
assessment_ids = []
exam_started = []
exam_names = []
certs = []
attempts = []
counts = []
questions = []
for item in data:
    if item['exam_name'].find('yeahsdf') > -1:
        continue
    exam_ids.append(item['base_exam_id'])
    assessment_ids.append(item['keen_id'])
    exam_started.append(item['started_at'])
    exam_names.append(item['exam_name'])
    certs.append(item['certification'])
    attempts.append(item['sequences']['attempt'])
    counts.append(item['sequences']['counts'])
    questions.append(item['sequences']['questions'])

# %%
print('# attempts per exam range from', min(attempts), 'to', max(attempts))
# Out:
# # attempts per exam range from 1 to 1

# %%
df_exams = pd.DataFrame()
df_exams['assessment_id'] = assessment_ids
df_exams['exam_id'] = exam_ids
df_exams['started_at'] = exam_started
df_exams['name'] = exam_names
df_exams['certification'] = certs
df_exams['attempts'] = attempts

df_counts = pd.DataFrame(counts)
df_exams = df_exams.join(df_counts)

# %%
df_exams.tail()
# Out:
#                  assessment_id                               exam_id  \
# 3270  5a3a4a5e63cb1c0001c01a0a  8b4488de-43a5-4ffa-bf82-af1e19ee1b64
# 3271  5a3a4a0eee88b10001cfb0a3  8b4488de-43a5-4ffa-bf82-af1e19ee1b64
# 3272  5a3a4a3ef646fe0001f73283  8b4488de-43a5-4ffa-bf82-af1e19ee1b64
# 3273  5a3a3f6b8c7fa00001d2a03e  f80366d9-db60-41c3-a1c4-6c7789b478f8
# 3274  5a3a3df2448eb200012a2efd  a62e5d35-75e9-11e6-8197-9801a7c3b233
#
#                     started_at                                  name  \
# 3270  2017-12-20T11:32:23.262Z                          Learning Git
# 3271  2017-12-20T11:29:09.015Z                          Learning Git
# 3272  2017-12-20T11:31:46.949Z                          Learning Git
# 3273  2017-12-20T10:44:09.162Z   I'm a Software Architect, Now What?
# 3274  2017-12-20T10:38:26.490Z  Learning Linux System Administration
#
#      certification  attempts  incomplete  submitted  incorrect  all_correct  \
# 3270         false         1           0          5          0         True
# 3271         false         1           0          5          2        False
# 3272         false         1           0          5          1        False
# 3273         false         1           1          4          0        False
# 3274         false         1           0          8          2        False
#
#       correct  total  unanswered
# 3270        5      5           0
# 3271        3      5           0
# 3272        4      5           0
# 3273        3      4           0
# 3274        6      8           0

# %% [markdown]
# # Other

# %%
df_questions = pd.DataFrame(questions)

# %%
df_questions
# Out:
#                                                      0   \
# 0     {'user_incomplete': True, 'user_correct': Fals...
# 1     {'user_incomplete': False, 'user_correct': Tru...
# 2     {'user_incomplete': False, 'user_correct': Fal...
# 3     {'user_incomplete': False, 'user_correct': Tru...
# 4     {'user_incomplete': False, 'user_correct': Fal...
# ...                                                 ...
# 3270  {'user_incomplete': False, 'user_correct': Tru...
# 3271  {'user_incomplete': False, 'user_correct': Tru...
# 3272  {'user_incomplete': False, 'user_correct': Tru...
# 3273  {'user_incomplete': False, 'user_correct': Tru...
# 3274  {'user_incomplete': False, 'user_correct': Tru...
#
#                                                      1   \
# 0     {'user_incomplete': False, 'user_correct': Fal...
# 1     {'user_incomplete': True, 'user_correct': Fals...
# 2     {'user_incomplete': False, 'user_correct': Tru...
# 3     {'user_incomplete': True, 'user_correct': Fals...
# 4     {'user_incomplete': False, 'user_correct': Tru...
# ...                                                 ...
# 3270  {'user_incomplete': False, 'user_correct': Tru...
# 3271  {'user_incomplete': False, 'user_correct': Tru...
# 3272  {'user_incomplete': False, 'user_correct': Tru...
# 3273  {'user_incomplete': False, 'user_correct': Tru...
# 3274  {'user_incomplete': False, 'user_correct': Tru...
#
#                                                      2   \
# 0     {'user_incomplete': False, 'user_correct': Tru...
# 1     {'user_incomplete': False, 'user_correct': Fal...
# 2     {'user_incomplete': False, 'user_correct': Tru...
# 3     {'user_incomplete': False, 'user_correct': Tru...
# 4     {'user_incomplete': False, 'user_correct': Tru...
# ...                                                 ...
# 3270  {'user_incomplete': False, 'user_correct': Tru...
# 3271  {'user_incomplete': False, 'user_correct': Fal...
# 3272  {'user_incomplete': False, 'user_correct': Fal...
# 3273  {'user_incomplete': True, 'user_correct': Fals...
# 3274  {'user_incomplete': False, 'user_correct': Tru...
#
#                                                      3   \
# 0     {'user_incomplete': False, 'user_correct': Tru...
# 1     {'user_incomplete': True, 'user_correct': Fals...
# 2     {'user_incomplete': False, 'user_correct': Tru...
# 3     {'user_incomplete': True, 'user_correct': Fals...
# 4     {'user_incomplete': False, 'user_correct': Tru...
# ...                                                 ...
# 3270  {'user_incomplete': False, 'user_correct': Tru...
# 3271  {'user_incomplete': False, 'user_correct': Fal...
# 3272  {'user_incomplete': False, 'user_correct': Tru...
# 3273  {'user_incomplete': False, 'user_correct': Tru...
# 3274  {'user_incomplete': False, 'user_correct': Tru...
#
#                                                      4   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3270  {'user_incomplete': False, 'user_correct': Tru...
# 3271  {'user_incomplete': False, 'user_correct': Tru...
# 3272  {'user_incomplete': False, 'user_correct': Tru...
# 3273                                               None
# 3274  {'user_incomplete': False, 'user_correct': Tru...
#
#                                                      5   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3270                                               None
# 3271                                               None
# 3272                                               None
# 3273                                               None
# 3274  {'user_incomplete': False, 'user_correct': Tru...
#
#                                                      6   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3270                                               None
# 3271                                               None
# 3272                                               None
# 3273                                               None
# 3274  {'user_incomplete': False, 'user_correct': Fal...
#
#                                                      7     8     9     10  \
# 0                                                  None  None  None  None
# 1                                                  None  None  None  None
# 2                                                  None  None  None  None
# 3                                                  None  None  None  None
# 4                                                  None  None  None  None
# ...                                                 ...   ...   ...   ...
# 3270                                               None  None  None  None
# 3271                                               None  None  None  None
# 3272                                               None  None  None  None
# 3273                                               None  None  None  None
# 3274  {'user_incomplete': False, 'user_correct': Fal...  None  None  None
#
#         11    12    13    14    15    16    17    18    19
# 0     None  None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3270  None  None  None  None  None  None  None  None  None
# 3271  None  None  None  None  None  None  None  None  None
# 3272  None  None  None  None  None  None  None  None  None
# 3273  None  None  None  None  None  None  None  None  None
# 3274  None  None  None  None  None  None  None  None  None
#
# [3275 rows x 20 columns]

# %%
len(df_exams[df_exams['name'].str.contains('Learning Git')==True])
# Out:
# 394

# %%
# show fields for each question
for blah in questions[0][0]:
    print(blah)
# Out:
# user_incomplete
# user_correct
# options
# user_submitted
# id
# user_result

# %%
len(questions)
# Out:
# 3275

# %%
for blah in questions[0]:
    for blahblah in blah:
        print(blahblah, blah[blahblah])
    for opt in blah['options']:
        print(opt)
    print('\n')
# Out:
# user_incomplete True
# user_correct False
# options [{'checked': True, 'at': '2018-01-23T14:23:24.670Z', 'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d', 'submitted': 1, 'correct': True}, {'checked': True, 'at': '2018-01-23T14:23:25.914Z', 'id': 'f2528210-35c3-4320-acf3-9056567ea19f', 'submitted': 1, 'correct': True}, {'checked': False, 'correct': True, 'id': 'd1bf026f-554f-4543-bdd2-54dcf105b826'}]
# user_submitted True
# id 7a2ed6d3-f492-49b3-b8aa-d080a8aad986
# user_result missed_some
# {'checked': True, 'at': '2018-01-23T14:23:24.670Z', 'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d', 'submitted': 1, 'correct': True}
# {'checked': True, 'at': '2018-01-23T14:23:25.914Z', 'id': 'f2528210-35c3-4320-acf3-9056567ea19f', 'submitted': 1, 'correct': True}
# {'checked': False, 'correct': True, 'id': 'd1bf026f-554f-4543-bdd2-54dcf105b826'}
#
#
# user_incomplete False
# user_correct False
# options [{'checked': True, 'at': '2018-01-23T14:23:30.116Z', 'id': 'a35d0e80-8c49-415d-b8cb-c21a02627e2b', 'submitted': 1}, {'checked': False, 'correct': True, 'id': 'bccd6e2e-2cef-4c72-8bfa-317db0ac48bb'}, {'checked': True, 'at': '2018-01-23T14:23:41.791Z', 'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b', 'submitted': 1, 'correct': True}]
# user_submitted True
# id bbed4358-999d-4462-9596-bad5173a6ecb
# user_result incorrect
# {'checked': True, 'at': '2018-01-23T14:23:30.116Z', 'id': 'a35d0e80-8c49-415d-b8cb-c21a02627e2b', 'submitted': 1}
# {'checked': False, 'correct': True, 'id': 'bccd6e2e-2cef-4c72-8bfa-317db0ac48bb'}
# {'checked': True, 'at': '2018-01-23T14:23:41.791Z', 'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b', 'submitted': 1, 'correct': True}
#
#
# user_incomplete False
# user_correct True
# options [{'checked': False, 'at': '2018-01-23T14:23:52.510Z', 'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732'}, {'checked': False, 'id': '85795acc-b4b1-4510-bd6e-41648a3553c9'}, {'checked': True, 'at': '2018-01-23T14:23:54.223Z', 'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909', 'submitted': 1, 'correct': True}, {'checked': True, 'at': '2018-01-23T14:23:53.862Z', 'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e', 'submitted': 1, 'correct': True}]
# user_submitted True
# id e6ad8644-96b1-4617-b37b-a263dded202c
# user_result correct
# {'checked': False, 'at': '2018-01-23T14:23:52.510Z', 'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732'}
# {'checked': False, 'id': '85795acc-b4b1-4510-bd6e-41648a3553c9'}
# {'checked': True, 'at': '2018-01-23T14:23:54.223Z', 'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909', 'submitted': 1, 'correct': True}
# {'checked': True, 'at': '2018-01-23T14:23:53.862Z', 'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e', 'submitted': 1, 'correct': True}
#
#
# user_incomplete False
# user_correct True
# options [{'checked': False, 'id': '59b9fc4b-f239-4850-b1f9-912d1fd3ca13'}, {'checked': False, 'id': '2c29e8e8-d4a8-406e-9cdf-de28ec5890fe'}, {'checked': False, 'id': '62feee6e-9b76-4123-bd9e-c0b35126b1f1'}, {'checked': True, 'at': '2018-01-23T14:24:00.807Z', 'id': '7f13df9c-fcbe-4424-914f-2206f106765c', 'submitted': 1, 'correct': True}]
# user_submitted True
# id 95194331-ac43-454e-83de-ea8913067055
# user_result correct
# {'checked': False, 'id': '59b9fc4b-f239-4850-b1f9-912d1fd3ca13'}
# {'checked': False, 'id': '2c29e8e8-d4a8-406e-9cdf-de28ec5890fe'}
# {'checked': False, 'id': '62feee6e-9b76-4123-bd9e-c0b35126b1f1'}
# {'checked': True, 'at': '2018-01-23T14:24:00.807Z', 'id': '7f13df9c-fcbe-4424-914f-2206f106765c', 'submitted': 1, 'correct': True}

# %%
total_correct = 0
total_wrong = 0
idx = 1
cnt_questions = len(questions[idx])
for exam in questions[idx]:
    cnt_correct = 0
    cnt_wrong = 0
    for option in exam['options']:
        if ('submitted' not in option):
            continue
        if ('correct' in option):
            if option['correct']:
                cnt_correct += 1
            else:
                cnt_wrong += 1
        else:
            cnt_wrong += 1
        print(option, cnt_correct)
    print('\n')
    if (cnt_correct > 0):
        total_correct += 1
    if (cnt_wrong > 0):
        total_wrong += 1

print('Detail\tQuestions = ', cnt_questions, 'Correct = ', total_correct, '\tIncorrect = ', total_wrong)
print('Summary\tQuestions = ', counts[idx]['total'], 'Correct = ', counts[idx]['correct'], '\tIncorrect = ', counts[idx]['incorrect'])
# Out:
# {'checked': True, 'at': '2018-01-23T14:22:04.301Z', 'id': '7f13df9c-fcbe-4424-914f-2206f106765c', 'submitted': 1, 'correct': True} 1
#
#
# {'checked': True, 'at': '2018-01-23T14:22:24.525Z', 'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b', 'submitted': 1, 'correct': True} 1
#
#
# {'checked': True, 'at': '2018-01-23T14:22:39.396Z', 'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909', 'submitted': 1, 'correct': True} 1
# {'checked': True, 'at': '2018-01-23T14:22:35.081Z', 'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e', 'submitted': 1, 'correct': True} 2
# {'checked': True, 'at': '2018-01-23T14:22:48.197Z', 'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732', 'submitted': 1} 2
#
#
# {'checked': True, 'at': '2018-01-23T14:22:55.494Z', 'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d', 'submitted': 1, 'correct': True} 1
#
#
# Detail	Questions =  4 Correct =  4 	Incorrect =  1
# Summary	Questions =  4 Correct =  1 	Incorrect =  1

# %%
questions[idx]
# Out:
# [{'user_incomplete': False,
#   'user_correct': True,
#   'options': [{'checked': False, 'id': '62feee6e-9b76-4123-bd9e-c0b35126b1f1'},
#    {'checked': True,
#     'at': '2018-01-23T14:22:04.301Z',
#     'id': '7f13df9c-fcbe-4424-914f-2206f106765c',
#     'submitted': 1,
#     'correct': True},
#    {'checked': False, 'id': '2c29e8e8-d4a8-406e-9cdf-de28ec5890fe'},
#    {'checked': False, 'id': '59b9fc4b-f239-4850-b1f9-912d1fd3ca13'}],
#   'user_submitted': True,
#   'id': '95194331-ac43-454e-83de-ea8913067055',
#   'user_result': 'correct'},
#  {'user_incomplete': True,
#   'user_correct': False,
#   'options': [{'checked': True,
#     'at': '2018-01-23T14:22:24.525Z',
#     'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b',
#     'submitted': 1,
#     'correct': True},
#    {'checked': False,
#     'correct': True,
#     'id': 'bccd6e2e-2cef-4c72-8bfa-317db0ac48bb'},
#    {'checked': False, 'id': 'a35d0e80-8c49-415d-b8cb-c21a02627e2b'}],
#   'user_submitted': True,
#   'id': 'bbed4358-999d-4462-9596-bad5173a6ecb',
#   'user_result': 'missed_some'},
#  {'user_incomplete': False,
#   'user_correct': False,
#   'options': [{'checked': True,
#     'at': '2018-01-23T14:22:39.396Z',
#     'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909',
#     'submitted': 1,
#     'correct': True},
#    {'checked': True,
#     'at': '2018-01-23T14:22:35.081Z',
#     'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e',
#     'submitted': 1,
#     'correct': True},
#    {'checked': False, 'id': '85795acc-b4b1-4510-bd6e-41648a3553c9'},
#    {'checked': True,
#     'at': '2018-01-23T14:22:48.197Z',
#     'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732',
#     'submitted': 1}],
#   'user_submitted': True,
#   'id': 'e6ad8644-96b1-4617-b37b-a263dded202c',
#   'user_result': 'incorrect'},
#  {'user_incomplete': True,
#   'user_correct': False,
#   'options': [{'checked': False,
#     'correct': True,
#     'id': 'd1bf026f-554f-4543-bdd2-54dcf105b826'},
#    {'checked': False,
#     'correct': True,
#     'id': 'f2528210-35c3-4320-acf3-9056567ea19f'},
#    {'checked': True,
#     'at': '2018-01-23T14:22:55.494Z',
#     'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d',
#     'submitted': 1,
#     'correct': True}],
#   'user_submitted': True,
#   'id': '7a2ed6d3-f492-49b3-b8aa-d080a8aad986',
#   'user_result': 'missed_some'}]

# %% [markdown]
# # Checking for duplicates

# %%
df_exams['assessment_id'].duplicated().value_counts()
# Out:
# False    3237
# True       38
# Name: assessment_id, dtype: int64

# %%
dup_ids = df_exams['assessment_id'][df_exams['assessment_id'].duplicated(keep=False)]
df_dupes = pd.DataFrame()
for dupe in dup_ids:
    df_dupes = df_dupes.append(df_exams[df_exams['assessment_id']==dupe])

# %%
df_dupes
# Out:
#                  assessment_id                               exam_id  \
# 461   5a4106a38149bb0001436a3d  8b4488de-43a5-4ffa-bf82-af1e19ee1b64
# 1053  5a4106a38149bb0001436a3d  8b4488de-43a5-4ffa-bf82-af1e19ee1b64
# 3118  5a4106a38149bb0001436a3d  8b4488de-43a5-4ffa-bf82-af1e19ee1b64
# 463   5a413176f21cc20001f47b56  1a233da8-e6e5-48a6-8c3c-806e312cce12
# 3120  5a413176f21cc20001f47b56  1a233da8-e6e5-48a6-8c3c-806e312cce12
# ...                        ...                                   ...
# 828   5a40a0cbdd34dc00014d8d64  94b741b2-fc67-4db4-adc2-aafae130848f
# 1032  5a40a0cbdd34dc00014d8d64  94b741b2-fc67-4db4-adc2-aafae130848f
# 3119  5a40a0cbdd34dc00014d8d64  94b741b2-fc67-4db4-adc2-aafae130848f
# 463   5a413176f21cc20001f47b56  1a233da8-e6e5-48a6-8c3c-806e312cce12
# 3120  5a413176f21cc20001f47b56  1a233da8-e6e5-48a6-8c3c-806e312cce12
#
#                     started_at                             name certification  \
# 461   2017-12-25T14:08:26.602Z                     Learning Git         false
# 1053  2017-12-25T14:08:26.602Z                     Learning Git         false
# 3118  2017-12-25T14:08:26.602Z                     Learning Git         false
# 463   2017-12-25T17:11:51.136Z  Intermediate Python Programming         false
# 3120  2017-12-25T17:11:51.136Z  Intermediate Python Programming         false
# ...                        ...                              ...           ...
# 828   2017-12-25T06:54:21.690Z      Intermediate C# Programming         false
# 1032  2017-12-25T06:54:21.690Z      Intermediate C# Programming         false
# 3119  2017-12-25T06:54:21.690Z      Intermediate C# Programming         false
# 463   2017-12-25T17:11:51.136Z  Intermediate Python Programming         false
# 3120  2017-12-25T17:11:51.136Z  Intermediate Python Programming         false
#
#       attempts  incomplete  submitted  incorrect  all_correct  correct  total  \
# 461          1           0          5          0         True        5      5
# 1053         1           0          5          0         True        5      5
# 3118         1           0          5          0         True        5      5
# 463          1           1          4          1        False        2      4
# 3120         1           1          4          1        False        2      4
# ...        ...         ...        ...        ...          ...      ...    ...
# 828          1           0          4          0         True        4      4
# 1032         1           0          4          0         True        4      4
# 3119         1           0          4          0         True        4      4
# 463          1           1          4          1        False        2      4
# 3120         1           1          4          1        False        2      4
#
#       unanswered
# 461            0
# 1053           0
# 3118           0
# 463            0
# 3120           0
# ...          ...
# 828            0
# 1032           0
# 3119           0
# 463            0
# 3120           0
#
# [170 rows x 13 columns]

# %%
df_dupes.duplicated(keep=False).value_counts()
# Out:
# True    170
# dtype: int64

# %%
df_diff_dupes = df_dupes[df_dupes.duplicated(keep=False)==False]

# %%
df_diff_dupes
# Out:
# Empty DataFrame
# Columns: [assessment_id, exam_id, started_at, name, certification, attempts, incomplete, submitted, incorrect, all_correct, correct, total, unanswered]
# Index: []

# %%
import json
for id in dup_ids[-1:]:
    print(df_questions[df_questions['assessment_id']==id]['question'].values, '\n\n')
# Out:
# [{'user_incomplete': False, 'user_correct': True, 'options': [{'checked': False, 'id': '7daed693-eaa0-4299-ac31-072fb9d4cd86'}, {'checked': False, 'at': '2017-12-25T17:10:23.841Z', 'id': 'b19c8abe-e2d1-4af1-824a-d2c10be41446'}, {'checked': False, 'id': '338cf4a1-e8ab-4751-9892-ee1cd0ee52d4'}, {'checked': True, 'at': '2017-12-25T17:10:26.415Z', 'id': 'fc820a68-189f-48c3-a5f6-f72775ae1985', 'submitted': 1, 'correct': True}], 'user_submitted': True, 'id': '32fe7d8d-6d89-4db4-a17a-a368c5ea3ca0', 'user_result': 'correct'}
#  {'user_incomplete': False, 'user_correct': False, 'options': [{'checked': False, 'id': '1284a320-bf24-4dfe-93d6-078a34731db3'}, {'checked': False, 'id': 'c3e76204-878f-4afb-85b9-1c0e408dd8e5'}, {'checked': False, 'correct': True, 'id': '2da628dc-44bb-4d27-a3f2-9198c793fb51'}, {'checked': True, 'at': '2017-12-25T17:10:35.776Z', 'id': '000db74a-f463-42e0-b07f-219653da78f1', 'submitted': 1}], 'user_submitted': True, 'id': '5c34cf19-8cfd-4f56-91c2-0a109dc990b9', 'user_result': 'incorrect'}
#  {'user_incomplete': False, 'user_correct': True, 'options': [{'checked': False, 'id': 'ba4b7f92-44e1-49ff-8eec-c08252921363'}, {'checked': False, 'id': '9764f37a-e28a-4ab8-b106-a9deaa58bc42'}, {'checked': False, 'id': '8d17b617-c021-4599-95ce-722b5785709a'}, {'checked': True, 'at': '2017-12-25T17:10:41.129Z', 'id': 'db4c8f7c-f4d7-4367-9117-52bd39246e14', 'submitted': 1, 'correct': True}], 'user_submitted': True, 'id': '803fc93f-7eb2-4121-af8c-ff809e850f10', 'user_result': 'correct'}
#  {'user_incomplete': True, 'user_correct': False, 'options': [{'checked': False, 'id': 'e25f1929-fb04-4c1e-849a-751d7b4b8a10'}, {'checked': False, 'correct': True, 'id': 'f3f1fdcc-80c1-4897-bf2a-45edcd3a3564'}, {'checked': False, 'id': '59f346f7-e92f-4860-bfb6-385eb041513d'}, {'checked': True, 'at': '2017-12-25T17:10:47.386Z', 'id': '724423f9-8028-4d0c-bbb4-069283d5cfa5', 'submitted': 1, 'correct': True}], 'user_submitted': True, 'id': 'f3cb88cc-5b79-41bb-96d3-7ec7d698b964', 'user_result': 'missed_some'}
#  {'user_incomplete': False, 'user_correct': True, 'options': [{'checked': False, 'id': '7daed693-eaa0-4299-ac31-072fb9d4cd86'}, {'checked': False, 'at': '2017-12-25T17:10:23.841Z', 'id': 'b19c8abe-e2d1-4af1-824a-d2c10be41446'}, {'checked': False, 'id': '338cf4a1-e8ab-4751-9892-ee1cd0ee52d4'}, {'checked': True, 'at': '2017-12-25T17:10:26.415Z', 'id': 'fc820a68-189f-48c3-a5f6-f72775ae1985', 'submitted': 1, 'correct': True}], 'user_submitted': True, 'id': '32fe7d8d-6d89-4db4-a17a-a368c5ea3ca0', 'user_result': 'correct'}
#  {'user_incomplete': False, 'user_correct': False, 'options': [{'checked': False, 'id': '1284a320-bf24-4dfe-93d6-078a34731db3'}, {'checked': False, 'id': 'c3e76204-878f-4afb-85b9-1c0e408dd8e5'}, {'checked': False, 'correct': True, 'id': '2da628dc-44bb-4d27-a3f2-9198c793fb51'}, {'checked': True, 'at': '2017-12-25T17:10:35.776Z', 'id': '000db74a-f463-42e0-b07f-219653da78f1', 'submitted': 1}], 'user_submitted': True, 'id': '5c34cf19-8cfd-4f56-91c2-0a109dc990b9', 'user_result': 'incorrect'}
#  {'user_incomplete': False, 'user_correct': True, 'options': [{'checked': False, 'id': 'ba4b7f92-44e1-49ff-8eec-c08252921363'}, {'checked': False, 'id': '9764f37a-e28a-4ab8-b106-a9deaa58bc42'}, {'checked': False, 'id': '8d17b617-c021-4599-95ce-722b5785709a'}, {'checked': True, 'at': '2017-12-25T17:10:41.129Z', 'id': 'db4c8f7c-f4d7-4367-9117-52bd39246e14', 'submitted': 1, 'correct': True}], 'user_submitted': True, 'id': '803fc93f-7eb2-4121-af8c-ff809e850f10', 'user_result': 'correct'}
#  {'user_incomplete': True, 'user_correct': False, 'options': [{'checked': False, 'id': 'e25f1929-fb04-4c1e-849a-751d7b4b8a10'}, {'checked': False, 'correct': True, 'id': 'f3f1fdcc-80c1-4897-bf2a-45edcd3a3564'}, {'checked': False, 'id': '59f346f7-e92f-4860-bfb6-385eb041513d'}, {'checked': True, 'at': '2017-12-25T17:10:47.386Z', 'id': '724423f9-8028-4d0c-bbb4-069283d5cfa5', 'submitted': 1, 'correct': True}], 'user_submitted': True, 'id': 'f3cb88cc-5b79-41bb-96d3-7ec7d698b964', 'user_result': 'missed_some'}]

# %%
e1 = data[data[0]['keen_id']==dup_ids.values[0]]
e2 = data[data[0]['keen_id']==dup_ids.values[-2]]

# %%
data['keen_id']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-329-0e48820ea97a> in <module>
# ----> 1 data['keen_id']
#
# TypeError: list indices must be integers or slices, not str

# %%
e1 == e2
# Out:
# True

# %%
e1
# Out:
# {'keen_timestamp': '1516717442.735266',
#  'max_attempts': '1.0',
#  'started_at': '2018-01-23T14:23:19.082Z',
#  'base_exam_id': '37f0a30a-7464-11e6-aa92-a8667f27e5dc',
#  'user_exam_id': '6d4089e4-bde5-4a22-b65f-18bce9ab79c8',
#  'sequences': {'questions': [{'user_incomplete': True,
#     'user_correct': False,
#     'options': [{'checked': True,
#       'at': '2018-01-23T14:23:24.670Z',
#       'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d',
#       'submitted': 1,
#       'correct': True},
#      {'checked': True,
#       'at': '2018-01-23T14:23:25.914Z',
#       'id': 'f2528210-35c3-4320-acf3-9056567ea19f',
#       'submitted': 1,
#       'correct': True},
#      {'checked': False,
#       'correct': True,
#       'id': 'd1bf026f-554f-4543-bdd2-54dcf105b826'}],
#     'user_submitted': True,
#     'id': '7a2ed6d3-f492-49b3-b8aa-d080a8aad986',
#     'user_result': 'missed_some'},
#    {'user_incomplete': False,
#     'user_correct': False,
#     'options': [{'checked': True,
#       'at': '2018-01-23T14:23:30.116Z',
#       'id': 'a35d0e80-8c49-415d-b8cb-c21a02627e2b',
#       'submitted': 1},
#      {'checked': False,
#       'correct': True,
#       'id': 'bccd6e2e-2cef-4c72-8bfa-317db0ac48bb'},
#      {'checked': True,
#       'at': '2018-01-23T14:23:41.791Z',
#       'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': 'bbed4358-999d-4462-9596-bad5173a6ecb',
#     'user_result': 'incorrect'},
#    {'user_incomplete': False,
#     'user_correct': True,
#     'options': [{'checked': False,
#       'at': '2018-01-23T14:23:52.510Z',
#       'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732'},
#      {'checked': False, 'id': '85795acc-b4b1-4510-bd6e-41648a3553c9'},
#      {'checked': True,
#       'at': '2018-01-23T14:23:54.223Z',
#       'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909',
#       'submitted': 1,
#       'correct': True},
#      {'checked': True,
#       'at': '2018-01-23T14:23:53.862Z',
#       'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': 'e6ad8644-96b1-4617-b37b-a263dded202c',
#     'user_result': 'correct'},
#    {'user_incomplete': False,
#     'user_correct': True,
#     'options': [{'checked': False,
#       'id': '59b9fc4b-f239-4850-b1f9-912d1fd3ca13'},
#      {'checked': False, 'id': '2c29e8e8-d4a8-406e-9cdf-de28ec5890fe'},
#      {'checked': False, 'id': '62feee6e-9b76-4123-bd9e-c0b35126b1f1'},
#      {'checked': True,
#       'at': '2018-01-23T14:24:00.807Z',
#       'id': '7f13df9c-fcbe-4424-914f-2206f106765c',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': '95194331-ac43-454e-83de-ea8913067055',
#     'user_result': 'correct'}],
#   'attempt': 1,
#   'id': '5b28a462-7a3b-42e0-b508-09f3906d1703',
#   'counts': {'incomplete': 1,
#    'submitted': 4,
#    'incorrect': 1,
#    'all_correct': False,
#    'correct': 2,
#    'total': 4,
#    'unanswered': 0}},
#  'keen_created_at': '1516717442.735266',
#  'certification': 'false',
#  'keen_id': '5a6745820eb8ab00016be1f1',
#  'exam_name': 'Normal Forms and All That Jazz Master Class'}

# %%
e2
# Out:
# {'keen_timestamp': '1516717442.735266',
#  'max_attempts': '1.0',
#  'started_at': '2018-01-23T14:23:19.082Z',
#  'base_exam_id': '37f0a30a-7464-11e6-aa92-a8667f27e5dc',
#  'user_exam_id': '6d4089e4-bde5-4a22-b65f-18bce9ab79c8',
#  'sequences': {'questions': [{'user_incomplete': True,
#     'user_correct': False,
#     'options': [{'checked': True,
#       'at': '2018-01-23T14:23:24.670Z',
#       'id': '49c574b4-5c82-4ffd-9bd1-c3358faf850d',
#       'submitted': 1,
#       'correct': True},
#      {'checked': True,
#       'at': '2018-01-23T14:23:25.914Z',
#       'id': 'f2528210-35c3-4320-acf3-9056567ea19f',
#       'submitted': 1,
#       'correct': True},
#      {'checked': False,
#       'correct': True,
#       'id': 'd1bf026f-554f-4543-bdd2-54dcf105b826'}],
#     'user_submitted': True,
#     'id': '7a2ed6d3-f492-49b3-b8aa-d080a8aad986',
#     'user_result': 'missed_some'},
#    {'user_incomplete': False,
#     'user_correct': False,
#     'options': [{'checked': True,
#       'at': '2018-01-23T14:23:30.116Z',
#       'id': 'a35d0e80-8c49-415d-b8cb-c21a02627e2b',
#       'submitted': 1},
#      {'checked': False,
#       'correct': True,
#       'id': 'bccd6e2e-2cef-4c72-8bfa-317db0ac48bb'},
#      {'checked': True,
#       'at': '2018-01-23T14:23:41.791Z',
#       'id': '7e0b639a-2ef8-4604-b7eb-5018bd81a91b',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': 'bbed4358-999d-4462-9596-bad5173a6ecb',
#     'user_result': 'incorrect'},
#    {'user_incomplete': False,
#     'user_correct': True,
#     'options': [{'checked': False,
#       'at': '2018-01-23T14:23:52.510Z',
#       'id': 'a9333679-de9d-41ff-bb3d-b239d6b95732'},
#      {'checked': False, 'id': '85795acc-b4b1-4510-bd6e-41648a3553c9'},
#      {'checked': True,
#       'at': '2018-01-23T14:23:54.223Z',
#       'id': 'c185ecdb-48fb-4edb-ae4e-0204ac7a0909',
#       'submitted': 1,
#       'correct': True},
#      {'checked': True,
#       'at': '2018-01-23T14:23:53.862Z',
#       'id': '77a66c83-d001-45cd-9a5a-6bba8eb7389e',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': 'e6ad8644-96b1-4617-b37b-a263dded202c',
#     'user_result': 'correct'},
#    {'user_incomplete': False,
#     'user_correct': True,
#     'options': [{'checked': False,
#       'id': '59b9fc4b-f239-4850-b1f9-912d1fd3ca13'},
#      {'checked': False, 'id': '2c29e8e8-d4a8-406e-9cdf-de28ec5890fe'},
#      {'checked': False, 'id': '62feee6e-9b76-4123-bd9e-c0b35126b1f1'},
#      {'checked': True,
#       'at': '2018-01-23T14:24:00.807Z',
#       'id': '7f13df9c-fcbe-4424-914f-2206f106765c',
#       'submitted': 1,
#       'correct': True}],
#     'user_submitted': True,
#     'id': '95194331-ac43-454e-83de-ea8913067055',
#     'user_result': 'correct'}],
#   'attempt': 1,
#   'id': '5b28a462-7a3b-42e0-b508-09f3906d1703',
#   'counts': {'incomplete': 1,
#    'submitted': 4,
#    'incorrect': 1,
#    'all_correct': False,
#    'correct': 2,
#    'total': 4,
#    'unanswered': 0}},
#  'keen_created_at': '1516717442.735266',
#  'certification': 'false',
#  'keen_id': '5a6745820eb8ab00016be1f1',
#  'exam_name': 'Normal Forms and All That Jazz Master Class'}

# %%
dup_ids
# Out:
# 825     5a4092ebdd97a30001a25bbb
# 827     5a40a188e258670001e8b2aa
# 829     5a40a15f08a89200018f3e1f
# 830     5a409fa0ea6e4b0001bc37f9
# 832     5a4130e6d919850001113a15
# 836     5a40b8baa87570000139bdb5
# 1030    5a4092ebdd97a30001a25bbb
# 1031    5a409fe6e433fd000152ae37
# 1032    5a40a0cbdd34dc00014d8d64
# 1033    5a40a15f08a89200018f3e1f
# 1034    5a409fa0ea6e4b0001bc37f9
# 1035    5a40a093b8237a000177d566
# 1036    5a40a00a81caf700019f4c3e
# 1053    5a4106a38149bb0001436a3d
# 1934    5a409fe6e433fd000152ae37
# 1935    5a40a1b45682ed0001fa29f5
# 1936    5a40a093b8237a000177d566
# 1937    5a40a244448eb2000193e31a
# 1938    5a40a20e475ca8000162d446
# 1939    5a40b8baa87570000139bdb5
# 1940    5a40a00a81caf700019f4c3e
# 2142    5a40162fe674e700011b223a
# 2143    5a4022f356c2d3000137a7cf
# 2144    5a40230c852c2a00018d4bd9
# 2145    5a401940fc03f00001313d9f
# 2146    5a403621a9207c00010fa8f3
# 2552    5a40162fe674e700011b223a
# 2553    5a4022f356c2d3000137a7cf
# 2554    5a40230c852c2a00018d4bd9
# 2556    5a401940fc03f00001313d9f
# 2693    5a40a188e258670001e8b2aa
# 2694    5a40a1b45682ed0001fa29f5
# 2695    5a40a244448eb2000193e31a
# 2696    5a40a20e475ca8000162d446
# 2884    5a403621a9207c00010fa8f3
# 3118    5a4106a38149bb0001436a3d
# 3119    5a40a0cbdd34dc00014d8d64
# 3120    5a413176f21cc20001f47b56
# Name: assessment_id, dtype: object
